# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
Iris=pd.read_csv("Iris_external.csv")

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
Iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
Iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
Iris.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.index = Iris['Class']

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2:3]
# Out:
#                 Petal length (in cm)
# Class
# Iris-setosa                      1.4
# Iris-setosa                      1.4
# Iris-setosa                      1.3
# Iris-setosa                      1.5
# Iris-setosa                      1.4
# Iris-setosa                      1.7
# Iris-setosa                      1.4
# Iris-setosa                      1.5
# Iris-setosa                      1.4
# Iris-setosa                      1.5
# Iris-setosa                      1.5
# Iris-setosa                      1.6
# Iris-setosa                      1.4
# Iris-setosa                      1.1
# Iris-setosa                      1.2
# Iris-setosa                      1.5
# Iris-setosa                      1.3
# Iris-setosa                      1.4
# Iris-setosa                      1.7
# Iris-setosa                      1.5
# Iris-setosa                      1.7
# Iris-setosa                      1.5
# Iris-setosa                      1.0
# Iris-setosa                      1.7
# Iris-setosa                      1.9
# Iris-setosa                      1.6
# Iris-setosa                      1.6
# Iris-setosa                      1.5
# Iris-setosa                      1.4
# Iris-setosa                      1.6
# ...                              ...
# Iris-virginica                   5.7
# Iris-virginica                   4.9
# Iris-virginica                   6.7
# Iris-virginica                   4.9
# Iris-virginica                   5.7
# Iris-virginica                   6.0
# Iris-virginica                   4.8
# Iris-virginica                   4.9
# Iris-virginica                   5.6
# Iris-virginica                   5.8
# Iris-virginica                   6.1
# Iris-virginica                   6.4
# Iris-virginica                   5.6
# Iris-virginica                   5.1
# Iris-virginica                   5.6
# Iris-virginica                   6.1
# Iris-virginica                   5.6
# Iris-virginica                   5.5
# Iris-virginica                   4.8
# Iris-virginica                   5.4
# Iris-virginica                   5.6
# Iris-virginica                   5.1
# Iris-virginica                   5.1
# Iris-virginica                   5.9
# Iris-virginica                   5.7
# Iris-virginica                   5.2
# Iris-virginica                   5.0
# Iris-virginica                   5.2
# Iris-virginica                   5.4
# Iris-virginica                   5.1
#
# [150 rows x 1 columns]

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.iloc[:10,:2]
# Out:
#              Sepal Length (in cm)  Sepal Width in (cm)
# Class
# Iris-setosa                   5.1                  3.5
# Iris-setosa                   4.9                  3.0
# Iris-setosa                   4.7                  3.2
# Iris-setosa                   4.6                  3.1
# Iris-setosa                   5.0                  3.6
# Iris-setosa                   5.4                  3.9
# Iris-setosa                   4.6                  3.4
# Iris-setosa                   5.0                  3.4
# Iris-setosa                   4.4                  2.9
# Iris-setosa                   4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris[Iris['Class']=="Iris-setosa"]
# Out:
#              Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# Class
# Iris-setosa                   5.1                  3.5                   1.4
# Iris-setosa                   4.9                  3.0                   1.4
# Iris-setosa                   4.7                  3.2                   1.3
# Iris-setosa                   4.6                  3.1                   1.5
# Iris-setosa                   5.0                  3.6                   1.4
# Iris-setosa                   5.4                  3.9                   1.7
# Iris-setosa                   4.6                  3.4                   1.4
# Iris-setosa                   5.0                  3.4                   1.5
# Iris-setosa                   4.4                  2.9                   1.4
# Iris-setosa                   4.9                  3.1                   1.5
# Iris-setosa                   5.4                  3.7                   1.5
# Iris-setosa                   4.8                  3.4                   1.6
# Iris-setosa                   4.8                  3.0                   1.4
# Iris-setosa                   4.3                  3.0                   1.1
# Iris-setosa                   5.8                  4.0                   1.2
# Iris-setosa                   5.7                  4.4                   1.5
# Iris-setosa                   5.4                  3.9                   1.3
# Iris-setosa                   5.1                  3.5                   1.4
# Iris-setosa                   5.7                  3.8                   1.7
# Iris-setosa                   5.1                  3.8                   1.5
# Iris-setosa                   5.4                  3.4                   1.7
# Iris-setosa                   5.1                  3.7                   1.5
# Iris-setosa                   4.6                  3.6                   1.0
# Iris-setosa                   5.1                  3.3                   1.7
# Iris-setosa                   4.8                  3.4                   1.9
# Iris-setosa                   5.0                  3.0                   1.6
# Iris-setosa                   5.0                  3.4                   1.6
# Iris-setosa                   5.2                  3.5                   1.5
# Iris-setosa                   5.2                  3.4                   1.4
# Iris-setosa                   4.7                  3.2                   1.6
# Iris-setosa                   4.8                  3.1                   1.6
# Iris-setosa                   5.4                  3.4                   1.5
# Iris-setosa                   5.2                  4.1                   1.5
# Iris-setosa                   5.5                  4.2                   1.4
# Iris-setosa                   4.9                  3.1                   1.5
# Iris-setosa                   5.0                  3.2                   1.2
# Iris-setosa                   5.5                  3.5                   1.3
# Iris-setosa                   4.9                  3.1                   1.5
# Iris-setosa                   4.4                  3.0                   1.3
# Iris-setosa                   5.1                  3.4                   1.5
# Iris-setosa                   5.0                  3.5                   1.3
# Iris-setosa                   4.5                  2.3                   1.3
# Iris-setosa                   4.4                  3.2                   1.3
# Iris-setosa                   5.0                  3.5                   1.6
# Iris-setosa                   5.1                  3.8                   1.9
# Iris-setosa                   4.8                  3.0                   1.4
# Iris-setosa                   5.1                  3.8                   1.6
# Iris-setosa                   4.6                  3.2                   1.4
# Iris-setosa                   5.3                  3.7                   1.5
# Iris-setosa                   5.0                  3.3                   1.4
#
#              Petal width (in cm)        Class
# Class
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.4  Iris-setosa
# Iris-setosa                  0.3  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.1  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.1  Iris-setosa
# Iris-setosa                  0.1  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.4  Iris-setosa
# Iris-setosa                  0.4  Iris-setosa
# Iris-setosa                  0.3  Iris-setosa
# Iris-setosa                  0.3  Iris-setosa
# Iris-setosa                  0.3  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.4  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.5  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.4  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.4  Iris-setosa
# Iris-setosa                  0.1  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.1  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.1  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.3  Iris-setosa
# Iris-setosa                  0.3  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.6  Iris-setosa
# Iris-setosa                  0.4  Iris-setosa
# Iris-setosa                  0.3  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa
# Iris-setosa                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris["SepalExtra"]=Iris["Sepal Length (in cm)"]* Iris["Sepal Width in (cm)"]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
Iris.mean()
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %%
Iris.var
# Out:
# <bound method DataFrame.var of                 Sepal Length (in cm)  Sepal Width in (cm)  \
# Class
# Iris-setosa                      5.1                  3.5
# Iris-setosa                      4.9                  3.0
# Iris-setosa                      4.7                  3.2
# Iris-setosa                      4.6                  3.1
# Iris-setosa                      5.0                  3.6
# Iris-setosa                      5.4                  3.9
# Iris-setosa                      4.6                  3.4
# Iris-setosa                      5.0                  3.4
# Iris-setosa                      4.4                  2.9
# Iris-setosa                      4.9                  3.1
# Iris-setosa                      5.4                  3.7
# Iris-setosa                      4.8                  3.4
# Iris-setosa                      4.8                  3.0
# Iris-setosa                      4.3                  3.0
# Iris-setosa                      5.8                  4.0
# Iris-setosa                      5.7                  4.4
# Iris-setosa                      5.4                  3.9
# Iris-setosa                      5.1                  3.5
# Iris-setosa                      5.7                  3.8
# Iris-setosa                      5.1                  3.8
# Iris-setosa                      5.4                  3.4
# Iris-setosa                      5.1                  3.7
# Iris-setosa                      4.6                  3.6
# Iris-setosa                      5.1                  3.3
# Iris-setosa                      4.8                  3.4
# Iris-setosa                      5.0                  3.0
# Iris-setosa                      5.0                  3.4
# Iris-setosa                      5.2                  3.5
# Iris-setosa                      5.2                  3.4
# Iris-setosa                      4.7                  3.2
# ...                              ...                  ...
# Iris-virginica                   6.9                  3.2
# Iris-virginica                   5.6                  2.8
# Iris-virginica                   7.7                  2.8
# Iris-virginica                   6.3                  2.7
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   7.2                  3.2
# Iris-virginica                   6.2                  2.8
# Iris-virginica                   6.1                  3.0
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   7.2                  3.0
# Iris-virginica                   7.4                  2.8
# Iris-virginica                   7.9                  3.8
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   6.3                  2.8
# Iris-virginica                   6.1                  2.6
# Iris-virginica                   7.7                  3.0
# Iris-virginica                   6.3                  3.4
# Iris-virginica                   6.4                  3.1
# Iris-virginica                   6.0                  3.0
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   6.7                  3.1
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   5.8                  2.7
# Iris-virginica                   6.8                  3.2
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   6.7                  3.0
# Iris-virginica                   6.3                  2.5
# Iris-virginica                   6.5                  3.0
# Iris-virginica                   6.2                  3.4
# Iris-virginica                   5.9                  3.0
#
#                 Petal length (in cm)  Petal width (in cm)           Class  \
# Class
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.3                  0.2     Iris-setosa
# Iris-setosa                      1.5                  0.2     Iris-setosa
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.7                  0.4     Iris-setosa
# Iris-setosa                      1.4                  0.3     Iris-setosa
# Iris-setosa                      1.5                  0.2     Iris-setosa
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.5                  0.1     Iris-setosa
# Iris-setosa                      1.5                  0.2     Iris-setosa
# Iris-setosa                      1.6                  0.2     Iris-setosa
# Iris-setosa                      1.4                  0.1     Iris-setosa
# Iris-setosa                      1.1                  0.1     Iris-setosa
# Iris-setosa                      1.2                  0.2     Iris-setosa
# Iris-setosa                      1.5                  0.4     Iris-setosa
# Iris-setosa                      1.3                  0.4     Iris-setosa
# Iris-setosa                      1.4                  0.3     Iris-setosa
# Iris-setosa                      1.7                  0.3     Iris-setosa
# Iris-setosa                      1.5                  0.3     Iris-setosa
# Iris-setosa                      1.7                  0.2     Iris-setosa
# Iris-setosa                      1.5                  0.4     Iris-setosa
# Iris-setosa                      1.0                  0.2     Iris-setosa
# Iris-setosa                      1.7                  0.5     Iris-setosa
# Iris-setosa                      1.9                  0.2     Iris-setosa
# Iris-setosa                      1.6                  0.2     Iris-setosa
# Iris-setosa                      1.6                  0.4     Iris-setosa
# Iris-setosa                      1.5                  0.2     Iris-setosa
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.6                  0.2     Iris-setosa
# ...                              ...                  ...             ...
# Iris-virginica                   5.7                  2.3  Iris-virginica
# Iris-virginica                   4.9                  2.0  Iris-virginica
# Iris-virginica                   6.7                  2.0  Iris-virginica
# Iris-virginica                   4.9                  1.8  Iris-virginica
# Iris-virginica                   5.7                  2.1  Iris-virginica
# Iris-virginica                   6.0                  1.8  Iris-virginica
# Iris-virginica                   4.8                  1.8  Iris-virginica
# Iris-virginica                   4.9                  1.8  Iris-virginica
# Iris-virginica                   5.6                  2.1  Iris-virginica
# Iris-virginica                   5.8                  1.6  Iris-virginica
# Iris-virginica                   6.1                  1.9  Iris-virginica
# Iris-virginica                   6.4                  2.0  Iris-virginica
# Iris-virginica                   5.6                  2.2  Iris-virginica
# Iris-virginica                   5.1                  1.5  Iris-virginica
# Iris-virginica                   5.6                  1.4  Iris-virginica
# Iris-virginica                   6.1                  2.3  Iris-virginica
# Iris-virginica                   5.6                  2.4  Iris-virginica
# Iris-virginica                   5.5                  1.8  Iris-virginica
# Iris-virginica                   4.8                  1.8  Iris-virginica
# Iris-virginica                   5.4                  2.1  Iris-virginica
# Iris-virginica                   5.6                  2.4  Iris-virginica
# Iris-virginica                   5.1                  2.3  Iris-virginica
# Iris-virginica                   5.1                  1.9  Iris-virginica
# Iris-virginica                   5.9                  2.3  Iris-virginica
# Iris-virginica                   5.7                  2.5  Iris-virginica
# Iris-virginica                   5.2                  2.3  Iris-virginica
# Iris-virginica                   5.0                  1.9  Iris-virginica
# Iris-virginica                   5.2                  2.0  Iris-virginica
# Iris-virginica                   5.4                  2.3  Iris-virginica
# Iris-virginica                   5.1                  1.8  Iris-virginica
#
#                 SepalExtra
# Class
# Iris-setosa          17.85
# Iris-setosa          14.70
# Iris-setosa          15.04
# Iris-setosa          14.26
# Iris-setosa          18.00
# Iris-setosa          21.06
# Iris-setosa          15.64
# Iris-setosa          17.00
# Iris-setosa          12.76
# Iris-setosa          15.19
# Iris-setosa          19.98
# Iris-setosa          16.32
# Iris-setosa          14.40
# Iris-setosa          12.90
# Iris-setosa          23.20
# Iris-setosa          25.08
# Iris-setosa          21.06
# Iris-setosa          17.85
# Iris-setosa          21.66
# Iris-setosa          19.38
# Iris-setosa          18.36
# Iris-setosa          18.87
# Iris-setosa          16.56
# Iris-setosa          16.83
# Iris-setosa          16.32
# Iris-setosa          15.00
# Iris-setosa          17.00
# Iris-setosa          18.20
# Iris-setosa          17.68
# Iris-setosa          15.04
# ...                    ...
# Iris-virginica       22.08
# Iris-virginica       15.68
# Iris-virginica       21.56
# Iris-virginica       17.01
# Iris-virginica       22.11
# Iris-virginica       23.04
# Iris-virginica       17.36
# Iris-virginica       18.30
# Iris-virginica       17.92
# Iris-virginica       21.60
# Iris-virginica       20.72
# Iris-virginica       30.02
# Iris-virginica       17.92
# Iris-virginica       17.64
# Iris-virginica       15.86
# Iris-virginica       23.10
# Iris-virginica       21.42
# Iris-virginica       19.84
# Iris-virginica       18.00
# Iris-virginica       21.39
# Iris-virginica       20.77
# Iris-virginica       21.39
# Iris-virginica       15.66
# Iris-virginica       21.76
# Iris-virginica       22.11
# Iris-virginica       20.10
# Iris-virginica       15.75
# Iris-virginica       19.50
# Iris-virginica       21.08
# Iris-virginica       17.70
#
# [150 rows x 6 columns]>

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def printFunction(a,b):
    print(a)
    print(b)

a=Iris.iloc[4:5,:1]
b=Iris.iloc[4:5,1:2]
printFunction(a , b)
# Out:
#              Sepal Length (in cm)
# Class
# Iris-setosa                   5.0
#              Sepal Width in (cm)
# Class
# Iris-setosa                  3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
Iris.head()
# Out:
#              Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# Class
# Iris-setosa                   5.1                  3.5                   1.4
# Iris-setosa                   4.9                  3.0                   1.4
# Iris-setosa                   4.7                  3.2                   1.3
# Iris-setosa                   4.6                  3.1                   1.5
# Iris-setosa                   5.0                  3.6                   1.4
#
#              Petal width (in cm)        Class  SepalExtra
# Class
# Iris-setosa                  0.2  Iris-setosa       17.85
# Iris-setosa                  0.2  Iris-setosa       14.70
# Iris-setosa                  0.2  Iris-setosa       15.04
# Iris-setosa                  0.2  Iris-setosa       14.26
# Iris-setosa                  0.2  Iris-setosa       18.00

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
def range(max,min):
    range=max-min
    print(range)

max= Iris["Sepal Length (in cm)"].max()
min=Iris["Sepal Length (in cm)"].min()
range( max,min)
# Out:
# 3.6000000000000005

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
max= Iris["Sepal Width in (cm)"].max()
min=Iris["Sepal Width in (cm)"].min()
range( max,min)
# Out:
# 2.4000000000000004

# %%
max=Iris["Petal width (in cm)"].max() 
min=Iris["Petal width (in cm)"].min()
range(max,min)
# Out:
# 2.4

# %%
max=Iris["SepalExtra"].max() 
min=Iris["SepalExtra"].min()
range(max,min)
# Out:
# 20.02

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
Iris.sort_values("Petal width (in cm)")
# Out:
#                 Sepal Length (in cm)  Sepal Width in (cm)  \
# Class
# Iris-setosa                      5.2                  4.1
# Iris-setosa                      4.3                  3.0
# Iris-setosa                      4.9                  3.1
# Iris-setosa                      4.9                  3.1
# Iris-setosa                      4.8                  3.0
# Iris-setosa                      4.9                  3.1
# Iris-setosa                      5.1                  3.5
# Iris-setosa                      5.2                  3.5
# Iris-setosa                      5.2                  3.4
# Iris-setosa                      4.7                  3.2
# Iris-setosa                      4.8                  3.1
# Iris-setosa                      5.5                  4.2
# Iris-setosa                      5.5                  3.5
# Iris-setosa                      4.4                  3.0
# Iris-setosa                      5.1                  3.4
# Iris-setosa                      4.4                  3.2
# Iris-setosa                      5.1                  3.8
# Iris-setosa                      4.6                  3.2
# Iris-setosa                      5.3                  3.7
# Iris-setosa                      5.0                  3.3
# Iris-setosa                      5.0                  3.0
# Iris-setosa                      4.8                  3.4
# Iris-setosa                      5.0                  3.2
# Iris-setosa                      4.6                  3.1
# Iris-setosa                      4.7                  3.2
# Iris-setosa                      5.0                  3.4
# Iris-setosa                      4.4                  2.9
# Iris-setosa                      5.4                  3.7
# Iris-setosa                      5.0                  3.6
# Iris-setosa                      4.8                  3.4
# ...                              ...                  ...
# Iris-virginica                   6.4                  2.7
# Iris-virginica                   5.6                  2.8
# Iris-virginica                   7.7                  2.8
# Iris-virginica                   6.5                  3.0
# Iris-virginica                   5.7                  2.5
# Iris-virginica                   7.9                  3.8
# Iris-virginica                   6.5                  3.2
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   7.1                  3.0
# Iris-virginica                   6.8                  3.0
# Iris-virginica                   7.6                  3.0
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   7.7                  3.8
# Iris-virginica                   6.4                  2.8
# Iris-virginica                   6.5                  3.0
# Iris-virginica                   6.9                  3.2
# Iris-virginica                   6.4                  3.2
# Iris-virginica                   6.2                  3.4
# Iris-virginica                   6.9                  3.1
# Iris-virginica                   6.8                  3.2
# Iris-virginica                   6.7                  3.0
# Iris-virginica                   7.7                  2.6
# Iris-virginica                   7.7                  3.0
# Iris-virginica                   6.3                  3.4
# Iris-virginica                   6.7                  3.1
# Iris-virginica                   5.8                  2.8
# Iris-virginica                   6.3                  3.3
# Iris-virginica                   6.7                  3.3
# Iris-virginica                   7.2                  3.6
#
#                 Petal length (in cm)  Petal width (in cm)           Class  \
# Class
# Iris-setosa                      1.5                  0.1     Iris-setosa
# Iris-setosa                      1.1                  0.1     Iris-setosa
# Iris-setosa                      1.5                  0.1     Iris-setosa
# Iris-setosa                      1.5                  0.1     Iris-setosa
# Iris-setosa                      1.4                  0.1     Iris-setosa
# Iris-setosa                      1.5                  0.1     Iris-setosa
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.5                  0.2     Iris-setosa
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.6                  0.2     Iris-setosa
# Iris-setosa                      1.6                  0.2     Iris-setosa
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.3                  0.2     Iris-setosa
# Iris-setosa                      1.3                  0.2     Iris-setosa
# Iris-setosa                      1.5                  0.2     Iris-setosa
# Iris-setosa                      1.3                  0.2     Iris-setosa
# Iris-setosa                      1.6                  0.2     Iris-setosa
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.5                  0.2     Iris-setosa
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.6                  0.2     Iris-setosa
# Iris-setosa                      1.9                  0.2     Iris-setosa
# Iris-setosa                      1.2                  0.2     Iris-setosa
# Iris-setosa                      1.5                  0.2     Iris-setosa
# Iris-setosa                      1.3                  0.2     Iris-setosa
# Iris-setosa                      1.5                  0.2     Iris-setosa
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.5                  0.2     Iris-setosa
# Iris-setosa                      1.4                  0.2     Iris-setosa
# Iris-setosa                      1.6                  0.2     Iris-setosa
# ...                              ...                  ...             ...
# Iris-virginica                   5.3                  1.9  Iris-virginica
# Iris-virginica                   4.9                  2.0  Iris-virginica
# Iris-virginica                   6.7                  2.0  Iris-virginica
# Iris-virginica                   5.2                  2.0  Iris-virginica
# Iris-virginica                   5.0                  2.0  Iris-virginica
# Iris-virginica                   6.4                  2.0  Iris-virginica
# Iris-virginica                   5.1                  2.0  Iris-virginica
# Iris-virginica                   5.4                  2.1  Iris-virginica
# Iris-virginica                   5.9                  2.1  Iris-virginica
# Iris-virginica                   5.5                  2.1  Iris-virginica
# Iris-virginica                   6.6                  2.1  Iris-virginica
# Iris-virginica                   5.7                  2.1  Iris-virginica
# Iris-virginica                   5.6                  2.1  Iris-virginica
# Iris-virginica                   6.7                  2.2  Iris-virginica
# Iris-virginica                   5.6                  2.2  Iris-virginica
# Iris-virginica                   5.8                  2.2  Iris-virginica
# Iris-virginica                   5.7                  2.3  Iris-virginica
# Iris-virginica                   5.3                  2.3  Iris-virginica
# Iris-virginica                   5.4                  2.3  Iris-virginica
# Iris-virginica                   5.1                  2.3  Iris-virginica
# Iris-virginica                   5.9                  2.3  Iris-virginica
# Iris-virginica                   5.2                  2.3  Iris-virginica
# Iris-virginica                   6.9                  2.3  Iris-virginica
# Iris-virginica                   6.1                  2.3  Iris-virginica
# Iris-virginica                   5.6                  2.4  Iris-virginica
# Iris-virginica                   5.6                  2.4  Iris-virginica
# Iris-virginica                   5.1                  2.4  Iris-virginica
# Iris-virginica                   6.0                  2.5  Iris-virginica
# Iris-virginica                   5.7                  2.5  Iris-virginica
# Iris-virginica                   6.1                  2.5  Iris-virginica
#
#                 SepalExtra
# Class
# Iris-setosa          21.32
# Iris-setosa          12.90
# Iris-setosa          15.19
# Iris-setosa          15.19
# Iris-setosa          14.40
# Iris-setosa          15.19
# Iris-setosa          17.85
# Iris-setosa          18.20
# Iris-setosa          17.68
# Iris-setosa          15.04
# Iris-setosa          14.88
# Iris-setosa          23.10
# Iris-setosa          19.25
# Iris-setosa          13.20
# Iris-setosa          17.34
# Iris-setosa          14.08
# Iris-setosa          19.38
# Iris-setosa          14.72
# Iris-setosa          19.61
# Iris-setosa          16.50
# Iris-setosa          15.00
# Iris-setosa          16.32
# Iris-setosa          16.00
# Iris-setosa          14.26
# Iris-setosa          15.04
# Iris-setosa          17.00
# Iris-setosa          12.76
# Iris-setosa          19.98
# Iris-setosa          18.00
# Iris-setosa          16.32
# ...                    ...
# Iris-virginica       17.28
# Iris-virginica       15.68
# Iris-virginica       21.56
# Iris-virginica       19.50
# Iris-virginica       14.25
# Iris-virginica       30.02
# Iris-virginica       20.80
# Iris-virginica       21.39
# Iris-virginica       21.30
# Iris-virginica       20.40
# Iris-virginica       22.80
# Iris-virginica       22.11
# Iris-virginica       17.92
# Iris-virginica       29.26
# Iris-virginica       17.92
# Iris-virginica       19.50
# Iris-virginica       22.08
# Iris-virginica       20.48
# Iris-virginica       21.08
# Iris-virginica       21.39
# Iris-virginica       21.76
# Iris-virginica       20.10
# Iris-virginica       20.02
# Iris-virginica       23.10
# Iris-virginica       21.42
# Iris-virginica       20.77
# Iris-virginica       16.24
# Iris-virginica       20.79
# Iris-virginica       22.11
# Iris-virginica       25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as num
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
HR = pd.read_csv('HR_external.txt',delimiter="\t")

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
HR.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
HR.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
HR.iloc[:,2:11]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# 5      32               2       1005           2                 2          2
# 6      59               1       1324           2                 3          3
# 7      30               1       1358           2                24          1
# 8      38               2        216           2                23          3
# 9      36               1       1299           2                27          3
# 10     35               1        809           2                16          3
# 11     29               1        153           2                15          2
# 12     31               1        670           2                26          1
# 13     34               1       1346           2                19          2
# 14     28               1        103           2                24          3
# 15     29               1       1389           2                21          4
# 16     32               1        334           2                 5          2
# 17     22               3       1123           2                16          2
# 18     53               1       1219           1                 2          4
# 19     38               1        371           2                 2          3
# 20     24               3        673           2                11          2
# 21     36               1       1218           1                 9          4
# 22     34               1        419           2                 7          4
# 23     21               1        391           2                15          2
# 24     34               1        699           2                 6          1
# 25     53               1       1282           2                 5          3
# 26     32               2       1125           2                16          1
# 27     42               1        691           1                 8          4
# 28     44               1        477           2                 7          4
# 29     46               1        705           1                 2          4
# ...   ...             ...        ...         ...               ...        ...
# 1440   36               2        688           2                 4          2
# 1441   56               3        667           2                 1          4
# 1442   29               1       1092           2                 1          4
# 1443   42               1        300           2                 2          3
# 1444   56               1        310           2                 7          2
# 1445   41               1        582           2                28          4
# 1446   34               1        704           1                28          3
# 1447   36               3        301           1                15          4
# 1448   41               1        930           1                 3          3
# 1449   32               1        529           2                 2          3
# 1450   35               1       1146           3                26          4
# 1451   38               1        345           1                10          2
# 1452   50               2        878           1                 1          4
# 1453   36               1       1120           1                11          4
# 1454   45               1        374           1                20          3
# 1455   40               1       1322           2                 2          4
# 1456   35               2       1199           2                18          4
# 1457   40               1       1194           2                 2          4
# 1458   35               1        287           2                 1          4
# 1459   29               1       1378           2                13          2
# 1460   29               1        468           2                28          4
# 1461   50               1        410           1                28          3
# 1462   39               1        722           1                24          1
# 1463   31               3        325           2                 5          3
# 1464   26               1       1167           1                 5          3
# 1465   36               2        884           2                23          2
# 1466   39               1        613           2                 6          1
# 1467   27               1        155           2                 4          3
# 1468   49               2       1023           1                 2          3
# 1469   34               1        628           2                 8          3
#
#       EducationField  EmployeeCount  EmployeeNumber
# 0                  1              1               1
# 1                  1              1               2
# 2                  6              1               4
# 3                  1              1               5
# 4                  2              1               7
# 5                  1              1               8
# 6                  2              1              10
# 7                  1              1              11
# 8                  1              1              12
# 9                  2              1              13
# 10                 2              1              14
# 11                 1              1              15
# 12                 1              1              16
# 13                 2              1              18
# 14                 1              1              19
# 15                 1              1              20
# 16                 1              1              21
# 17                 2              1              22
# 18                 1              1              23
# 19                 1              1              24
# 20                 6              1              26
# 21                 1              1              27
# 22                 1              1              28
# 23                 1              1              30
# 24                 2              1              31
# 25                 6              1              32
# 26                 1              1              33
# 27                 3              1              35
# 28                 2              1              36
# 29                 3              1              38
# ...              ...            ...             ...
# 1440               1              1            2025
# 1441               1              1            2026
# 1442               2              1            2027
# 1443               1              1            2031
# 1444               4              1            2032
# 1445               1              1            2034
# 1446               3              1            2035
# 1447               3              1            2036
# 1448               1              1            2037
# 1449               4              1            2038
# 1450               1              1            2040
# 1451               1              1            2041
# 1452               1              1            2044
# 1453               3              1            2045
# 1454               1              1            2046
# 1455               1              1            2048
# 1456               1              1            2049
# 1457               2              1            2051
# 1458               1              1            2052
# 1459               6              1            2053
# 1460               2              1            2054
# 1461               3              1            2055
# 1462               3              1            2056
# 1463               2              1            2057
# 1464               6              1            2060
# 1465               2              1            2061
# 1466               2              1            2062
# 1467               1              1            2064
# 1468               2              1            2065
# 1469               2              1            2068
#
# [1470 rows x 9 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
HR["Gender"].head()
# Out:
# 0    2
# 1    1
# 2    1
# 3    2
# 4    1
# Name: Gender, dtype: int64

# %%
HR['Gender'].value_counts()
# Out:
# 1    882
# 2    588
# Name: Gender, dtype: int64

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
Q1=HR['Age'].quantile(.25)
Q2=HR['Age'].quantile(.75)
IQR=Q2-Q1

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
HR['DailyRate'].mean()
# Out:
# 802.4857142857143

# %%
HR['DailyRate'].median()
# Out:
# 802.0

# %%
HR['DailyRate'].var()
# Out:
# 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import seaborn as sns
sns.countplot(x="Attrition", data=HR);

# %% [markdown]
# ### Plot Total working years using matplotlib plot function
